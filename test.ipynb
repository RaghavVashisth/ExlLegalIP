# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
clusters = {
    "Quick Closers": np.random.randn(30, 2) + [-2, 1],
    "High Severity, Long-Tail Litigators": np.random.randn(40, 2),
    "High Cost Firms": np.random.randn(25, 2) + [2, 1],
    "Volume Handlers": np.random.randn(30, 2) + [2, -1]
}

fig, ax = plt.subplots(figsize=(7, 4))
for name, pts in clusters.items():
    ax.scatter(pts[:, 0], pts[:, 1], label=name, alpha=0.6)

ax.scatter(0, 0, s=180, c="black")
ax.text(0, 0.1, "This Claim", ha="center")

ax.set_xticks([])
ax.set_yticks([])
ax.legend(fontsize=8)
st.pyplot(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 19
#      17 ax.set_yticks([])
#      18 ax.legend(fontsize=8)
# ---> 19 st.pyplot(fig)
#
# NameError: name 'st' is not defined

# %%
with left:
    st.subheader("Legal Market Segment Identification")

    # Load real cluster mapping
    df = pd.read_csv("firm_cluster_mapping.csv")

    # Assign fixed centers for each cluster (for visualization)
    cluster_centers = {
        "Quick Closers": (-2, 1),
        "High Severity, Long-Tail Litigators": (0, 0),
        "High Cost Firms": (2, 1),
        "Volume Handlers": (2, -1)
    }

    # Create X, Y with small jitter so points don't overlap
    np.random.seed(42)
    df["x"] = df["Cluster"].apply(lambda c: cluster_centers[c][0]) + np.random.normal(0, 0.25, len(df))
    df["y"] = df["Cluster"].apply(lambda c: cluster_centers[c][1]) + np.random.normal(0, 0.25, len(df))

    fig, ax = plt.subplots(figsize=(7, 4))

    # Plot each cluster
    for cluster, grp in df.groupby("Cluster"):
        ax.scatter(grp["x"], grp["y"], label=cluster, alpha=0.6)

    # Highlight current claim (optional anchor)
    ax.scatter(0, 0, s=200, c="black")
    ax.text(0, 0.12, "This Claim", ha="center", fontsize=9)

    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(fontsize=8)
    ax.set_title("Legal Firm Clustering Map")

    st.pyplot(fig)

# %%
with left:
    st.subheader("Legal Market Segment Identification")

    # Load real cluster mapping
    df = pd.read_csv("firm_cluster_mapping.csv")

    # Assign fixed centers for each cluster (for visualization)
    cluster_centers = {
        "Quick Closers": (-2, 1),
        "High Severity, Long-Tail Litigators": (0, 0),
        "High Cost Firms": (2, 1),
        "Volume Handlers": (2, -1)
    }

    # Create X, Y with small jitter so points don't overlap
    np.random.seed(42)
    df["x"] = df["Cluster"].apply(lambda c: cluster_centers[c][0]) + np.random.normal(0, 0.25, len(df))
    df["y"] = df["Cluster"].apply(lambda c: cluster_centers[c][1]) + np.random.normal(0, 0.25, len(df))

    fig, ax = plt.subplots(figsize=(7, 4))

    # Plot each cluster
    for cluster, grp in df.groupby("Cluster"):
        ax.scatter(grp["x"], grp["y"], label=cluster, alpha=0.6)

    # Highlight current claim (optional anchor)
    ax.scatter(0, 0, s=200, c="black")
    ax.text(0, 0.12, "This Claim", ha="center", fontsize=9)

    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(fontsize=8)
    ax.set_title("Legal Firm Clustering Map")

    st.pyplot(fig)
